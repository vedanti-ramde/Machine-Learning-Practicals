# %% [markdown]
# Practical No 8
#
# Aim:- To apply Principal Component Analysis for dimensionality reduction and visualize the transformed feature space.
#
# Name:Vedanti Ramde
#
# Roll No:CS23153

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
iris = load_iris()
X = iris.data
y = iris.target

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
print("Explained Variable Ratio:",
      pca.explained_variance_ratio_)
# Out:
# Explained Variable Ratio: [0.72962445 0.22850762]

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_pca[:,0],X_pca[:,1],c=y)
plt.xlabel("Principal Components 1")
plt.ylabel("Principal Components 2")
plt.title("PCA - Iris Dataset")
plt.colorbar()
plt.show()

# %%
pca = PCA()
pca.fit(X_scaled)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Explained Varience")
plt.show()
